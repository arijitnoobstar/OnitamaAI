# %%
from play_onitama import *

# %%
game_mode = "minimax v p"
play_onitama(game_mode, first_move = None, 
    verbose = 1, minimax_depth = 5, 
    minimax_depth_red = None, minimax_depth_blue = None, 
    aivai_turns = 500, timeLimit=None, iterationLimit=None, 
    iteration_red = None, iteration_blue = None, 
    mcts_efficiency = "space", parallel = None)
# Out:
# Turn 1
#
# current board:
#
# b1 b2 B  b3 b4
# •  •  •  •  •
# •  •  •  •  •
# •  •  •  •  •
# r1 r2 R  r3 r4
#
# player's (blue) moves available:
#
# boar:            tiger:
# ◦ ◦ ◦ ◦ ◦ 	 ◦ ◦ ◦ ◦ ◦
# ◦ ◦ ◦ ◦ ◦ 	 ◦ ◦ B ◦ ◦
# ◦ B ☺ C ◦ 	 ◦ ◦ ☺ ◦ ◦
# ◦ ◦ A ◦ ◦ 	 ◦ ◦ ◦ ◦ ◦
# ◦ ◦ ◦ ◦ ◦ 	 ◦ ◦ A ◦ ◦
#
#
# opponent (red) moves available:
#
# rabbit:          cobra:
# ◦ ◦ ◦ ◦ ◦ 	 ◦ ◦ ◦ ◦ ◦
# ◦ ◦ ◦ A ◦ 	 ◦ ◦ ◦ B ◦
# ◦ ◦ ☺ ◦ B 	 ◦ A ☺ ◦ ◦
# ◦ C ◦ ◦ ◦ 	 ◦ ◦ ◦ C ◦
# ◦ ◦ ◦ ◦ ◦ 	 ◦ ◦ ◦ ◦ ◦
#
#
# side move:
#
# eel:
# ◦ ◦ ◦ ◦ ◦
# ◦ ◦ ◦ B ◦
# ◦ C ☺ ◦ ◦
# ◦ ◦ ◦ A ◦
# ◦ ◦ ◦ ◦ ◦
#
# ['boar', 'C']
# entered invalid string
# ['Boar', 'C']
# entered invalid string
# ['b1', 'boar', 'c']
# a blue piece cannot take the place of another blue piece. please reselect move
# ['']
# entered invalid string
# ['']
# entered invalid string
# ['']
# entered invalid string
# ['']
# entered invalid string
# ['']
# entered invalid string
# ['']
# entered invalid string
# ['']
# entered invalid string
# ['']
# ...
